# %%
#Dillon

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("training.csv")
df["Day of week"] = df["dayOfTheYear"]%7 + 1

store_1 = df[df["StoreNumber"] == 1000]
store_2 = df[df["StoreNumber"] == 2000]
store_3 = df[df["StoreNumber"] == 3000]
store_4 = df[df["StoreNumber"] == 4000]

x_data = df.iloc[:, 0].values.reshape(-1,1)
y_data = df.iloc[:, 1].values.reshape(-1,1)

temp = store_1

# %%
#store_11 = store_1[store_1["3HourBucket"] == 4]

plt.scatter(store_11["dayOfTheYear"], store_11["GrossSoldQuantity"])
plt.xlabel("Day of Year")
plt.ylabel("Gross Sold")
plt.grid(True)
plt.show()

df
# Out:
#       StoreNumber  dayOfTheYear  3HourBucket  GrossSoldQuantity  \
# 0            1000             1            1                  3
# 1            1000             1            2                  5
# 2            1000             1            3                  6
# 3            1000             1            4                  3
# 4            1000             2            1                 13
# ...           ...           ...          ...                ...
# 5655         4000           362            2                 20
# 5656         4000           362            3                 26
# 5657         4000           362            4                 37
# 5658         4000           363            3                 27
# 5659         4000           363            4                 43
#
#       Cash/Credit Site  EBT Site  Loyalty Site  ExtraMile Site CoBrand  \
# 0                False      True          True            True      No
# 1                False      True          True            True      No
# 2                False      True          True            True      No
# 3                False      True          True            True      No
# 4                False      True          True            True      No
# ...                ...       ...           ...             ...     ...
# 5655             False     False          True            True      No
# 5656             False     False          True            True      No
# 5657             False     False          True            True      No
# 5658             False     False          True            True      No
# 5659             False     False          True            True      No
#
#       Alcohol  Carwash  Food Service         City State  Day of week
# 0        True    False          True      HOUSTON    TX            2
# 1        True    False          True      HOUSTON    TX            2
# 2        True    False          True      HOUSTON    TX            2
# 3        True    False          True      HOUSTON    TX            2
# 4        True    False          True      HOUSTON    TX            3
# ...       ...      ...           ...          ...   ...          ...
# 5655    False     True          True  SAN ANTONiO    TX            6
# 5656    False     True          True  SAN ANTONiO    TX            6
# 5657    False     True          True  SAN ANTONiO    TX            6
# 5658    False     True          True  SAN ANTONiO    TX            7
# 5659    False     True          True  SAN ANTONiO    TX            7
#
# [5660 rows x 15 columns]

# %%
plt.scatter(store_2["dayOfTheYear"], store_2["GrossSoldQuantity"])
plt.xlabel("Day of Year")
plt.ylabel("Gross Sold")
plt.grid(True)
plt.show()

# %%
plt.scatter(store_3["dayOfTheYear"], store_3["GrossSoldQuantity"])
plt.xlabel("Day of Year")
plt.ylabel("Gross Sold")
plt.grid(True)
plt.show()

# %%
plt.scatter(store_4["dayOfTheYear"], store_4["GrossSoldQuantity"])
plt.xlabel("Day of Year")
plt.ylabel("Gross Sold")
plt.grid(True)
plt.show()

# %%
store1 = df[df["StoreNumber"] == 1000]
store2 = df[df["StoreNumber"] == 2000]
store3 = df[df["StoreNumber"] == 3000]
store4 = df[df["StoreNumber"] == 4000]

bucket1 = df[df["3HourBucket"] == 1]
bucket2 = df[df["3HourBucket"] == 2]
bucket3 = df[df["3HourBucket"] == 3]
bucket4 = df[df["3HourBucket"] == 4]
store_11 = pd.merge(store1, bucket1)

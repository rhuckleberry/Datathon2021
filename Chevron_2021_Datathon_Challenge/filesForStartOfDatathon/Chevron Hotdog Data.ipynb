# %%
import pandas as pd
import numpy
import scipy

# %%
data = pd.read_csv("./training.csv")

# %%
data
# Out:
#       StoreNumber  dayOfTheYear  3HourBucket  GrossSoldQuantity  \
# 0            1000             1            1                  3
# 1            1000             1            2                  5
# 2            1000             1            3                  6
# 3            1000             1            4                  3
# 4            1000             2            1                 13
# ...           ...           ...          ...                ...
# 5655         4000           362            2                 20
# 5656         4000           362            3                 26
# 5657         4000           362            4                 37
# 5658         4000           363            3                 27
# 5659         4000           363            4                 43
#
#       Cash/Credit Site  EBT Site  Loyalty Site  ExtraMile Site CoBrand  \
# 0                False      True          True            True      No
# ...
